# %% [markdown]
# <a href="https://colab.research.google.com/github/KauaMenezees/GSIA/blob/main/GSIAV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="206yLtqXls5wCb8kq7L3")
project = rf.workspace("unuja").project("deteksiplastik")
version = project.version(4)
model = project.version(4).model
dataset = version.download("coco")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DeteksiPlastik-4 in coco:: 100%|██████████| 82/82 [00:00<00:00, 4775.78it/s]

# %%
print(model.predict("/content/DeteksiPlastik-4/train/112_jpg.rf.32a7320cca16fa457492d403eafeb3f1.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 281.0, 'y': 164.5, 'width': 106.0, 'height': 197.0, 'confidence': 0.9010679721832275, 'class': 'plastik', 'class_id': 0, 'detection_id': '46ae0074-2e72-456d-9b90-d1d8720a2b6b', 'image_path': '/content/DeteksiPlastik-4/train/112_jpg.rf.32a7320cca16fa457492d403eafeb3f1.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 173.0, 'y': 92.0, 'width': 108.0, 'height': 180.0, 'confidence': 0.8603622913360596, 'class': 'plastik', 'class_id': 0, 'detection_id': 'e23ccf77-11a2-44ed-89be-a345c1521bbc', 'image_path': '/content/DeteksiPlastik-4/train/112_jpg.rf.32a7320cca16fa457492d403eafeb3f1.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 149.5, 'y': 236.5, 'width': 117.0, 'height': 177.0, 'confidence': 0.8596327304840088, 'class': 'plastik', 'class_id': 0, 'detection_id': '2744256b-2890-4abc-a241-de0747aeebab', 'image_path': '/content/DeteksiPlastik-4/train/112_jpg.rf.32a7320cca16fa457492d403eafeb3f1.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': 
# ...

# %%
model.predict("/content/DeteksiPlastik-4/train/112_jpg.rf.32a7320cca16fa457492d403eafeb3f1.jpg", confidence=40, overlap=30).save("/content/DeteksiPlastik-4/train/125_jpg.rf.6057134f799c4ae1759ecb4bdef4b553.jpg")

# %%
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow


resultado = cv2.imread('/content/DeteksiPlastik-4/train/125_jpg.rf.6057134f799c4ae1759ecb4bdef4b553.jpg')
cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>
